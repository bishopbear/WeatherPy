# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
import citipy
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Starting URL for Weather Map API Call.
# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f3e55d4c20608243ac8f8d7103058003

# %%
# Import the datetime module from the datetime library.
import time
from datetime import datetime

# Import the requests library.
import requests

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | alofi
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | inuvik
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | kamina
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | kitimat
# Processing Record 15 of Set 1 | mlada vozice
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | clyde river
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 1 | bo
# City not found. Skipping...
# Processing Record 30 of Set 1 | roma
# Processing Record 31 of Set 1 | mecca
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | oxford
# Processing Record 34 of Set 1 | tuatapere
# Processing Record 35 of Set 1 | launceston
# Processing Record 36 of Set 1 | vostok
# Processing Record 37 of Set 1 | soyo
# Processing Record 38 of Set 1 | vanavara
# Processing Record 39 of Set 1 | aksarayskiy
# Processing Record 40 of Set 1 | kyshtovka
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | faanui
# Processing Record 43 of Set 1 | grand-lahou
# Processing Record 44 of Set 1 | ust-kuyga
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | sabha
# Processing Record 47 of Set 1 | richards bay
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | rawson
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | lamu
# Processing Record 4 of Set 2 | malindi
# Processing Record 5 of Set 2 | yarmouth
# Processing Record 6 of Set 2 | hay river
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | ilhabela
# Processing Record 10 of Set 2 | dakoro
# Processing Record 11 of Set 2 | gayny
# Processing Record 12 of Set 2 | long
# Processing Record 13 of Set 2 | basco
# Processing Record 14 of Set 2 | ocotlan
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | narasannapeta
# Processing Record 18 of Set 2 | skibbereen
# Processing Record 19 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 2 | brae
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | portland
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | juegang
# Processing Record 26 of Set 2 | namibe
# Processing Record 27 of Set 2 | huarmey
# Processing Record 28 of Set 2 | plettenberg bay
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | forbes
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | flinders
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | hambantota
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 2 | dedza
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 | manadhoo
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | sanquhar
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | mponela
# Processing Record 50 of Set 2 | noumea
# Processing Record 1 of Set 3 | antofagasta
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | benghazi
# Processing Record 5 of Set 3 | nova olimpia
# Processing Record 6 of Set 3 | izazi
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | busselton
# Processing Record 9 of Set 3 | katherine
# Processing Record 10 of Set 3 | limenaria
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | kaifeng
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | mlalo
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | boyolangu
# Processing Record 17 of Set 3 | nuuk
# Processing Record 18 of Set 3 | carutapera
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | bilibino
# Processing Record 22 of Set 3 | trofors
# Processing Record 23 of Set 3 | lagoa
# Processing Record 24 of Set 3 | pilar
# Processing Record 25 of Set 3 | kapuskasing
# Processing Record 26 of Set 3 | carauari
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | coihaique
# Processing Record 29 of Set 3 | sept-iles
# Processing Record 30 of Set 3 | girvan
# Processing Record 31 of Set 3 | santa rosa
# Processing Record 32 of Set 3 | itarema
# Processing Record 33 of Set 3 | polyarnyy
# Processing Record 34 of Set 3 | mayo
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 3 | constitucion
# Processing Record 39 of Set 3 | jinchang
# Processing Record 40 of Set 3 | nizhnevartovsk
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | mikhaylovka
# Processing Record 44 of Set 3 | jinka
# Processing Record 45 of Set 3 | kommunisticheskiy
# Processing Record 46 of Set 3 | kaitangata
# Processing Record 47 of Set 3 | vardo
# Processing Record 48 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 49 of Set 3 | mahanoro
# Processing Record 50 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 4 | namie
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 4 | port hardy
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 4 | tianpeng
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | karpathos
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | san rafael del sur
# Processing Record 13 of Set 4 | kjollefjord
# Processing Record 14 of Set 4 | derzhavinsk
# Processing Record 15 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | aloja
# Processing Record 18 of Set 4 | havre-saint-pierre
# Processing Record 19 of Set 4 | tari
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | ormara
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | vao
# Processing Record 24 of Set 4 | zhezkazgan
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | beysehir
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | san quintin
# Processing Record 29 of Set 4 | wasilla
# Processing Record 30 of Set 4 | north platte
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 4 | biak
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | acapulco
# Processing Record 37 of Set 4 | talnakh
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 4 | saint-leu
# Processing Record 41 of Set 4 | vulcan
# Processing Record 42 of Set 4 | new norfolk
# Processing Record 43 of Set 4 | luanda
# Processing Record 44 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | olinda
# Processing Record 47 of Set 4 | nantucket
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | humaita
# Processing Record 50 of Set 4 | reconquista
# Processing Record 1 of Set 5 | smithers
# Processing Record 2 of Set 5 | arraial do cabo
# Processing Record 3 of Set 5 | palmer
# Processing Record 4 of Set 5 | luebo
# Processing Record 5 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 5 | yugorsk
# Processing Record 7 of Set 5 | ponta delgada
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | namatanai
# Processing Record 10 of Set 5 | den helder
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | the valley
# Processing Record 13 of Set 5 | lufilufi
# Processing Record 14 of Set 5 | lompoc
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | snyder
# Processing Record 18 of Set 5 | xiaoweizhai
# Processing Record 19 of Set 5 | bambous virieux
# Processing Record 20 of Set 5 | gayeri
# Processing Record 21 of Set 5 | abdanan
# Processing Record 22 of Set 5 | fuyang
# Processing Record 23 of Set 5 | west bay
# Processing Record 24 of Set 5 | kodinsk
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | nhulunbuy
# Processing Record 27 of Set 5 | tornio
# Processing Record 28 of Set 5 | oranjemund
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | san ramon de la nueva oran
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | bonfim
# Processing Record 33 of Set 5 | anadyr
# Processing Record 34 of Set 5 | birin
# Processing Record 35 of Set 5 | porto nacional
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | pochutla
# Processing Record 39 of Set 5 | jalu
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | baoshan
# Processing Record 42 of Set 5 | soe
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | abu samrah
# Processing Record 45 of Set 5 | pangnirtung
# Processing Record 46 of Set 5 | banepa
# Processing Record 47 of Set 5 | sola
# Processing Record 48 of Set 5 | wanning
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | hami
# Processing Record 1 of Set 6 | dawson
# Processing Record 2 of Set 6 | omboue
# Processing Record 3 of Set 6 | les cayes
# Processing Record 4 of Set 6 | merzifon
# Processing Record 5 of Set 6 | maldonado
# Processing Record 6 of Set 6 | montepuez
# Processing Record 7 of Set 6 | goya
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | suntar
# Processing Record 11 of Set 6 | la romana
# Processing Record 12 of Set 6 | masty
# Processing Record 13 of Set 6 | vestmanna
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | norman wells
# Processing Record 16 of Set 6 | bonavista
# Processing Record 17 of Set 6 | dera ghazi khan
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | goundam
# Processing Record 23 of Set 6 | airai
# Processing Record 24 of Set 6 | san borja
# Processing Record 25 of Set 6 | tel aviv-yafo
# Processing Record 26 of Set 6 | vila velha
# Processing Record 27 of Set 6 | arrecife
# Processing Record 28 of Set 6 | tytuvenai
# Processing Record 29 of Set 6 | wakkanai
# Processing Record 30 of Set 6 | alexandria
# Processing Record 31 of Set 6 | ciudad bolivar
# Processing Record 32 of Set 6 | nagod
# Processing Record 33 of Set 6 | laurel
# Processing Record 34 of Set 6 | otradnoye
# Processing Record 35 of Set 6 | roebourne
# Processing Record 36 of Set 6 | boden
# Processing Record 37 of Set 6 | barcelos
# Processing Record 38 of Set 6 | la rioja
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | tilichiki
# Processing Record 41 of Set 6 | moryakovskiy zaton
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | russell
# Processing Record 44 of Set 6 | labytnangi
# Processing Record 45 of Set 6 | raduzhnyy
# Processing Record 46 of Set 6 | peace river
# Processing Record 47 of Set 6 | mackay
# Processing Record 48 of Set 6 | hovd
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | kerema
# Processing Record 1 of Set 7 | xinzhou
# Processing Record 2 of Set 7 | kaoma
# Processing Record 3 of Set 7 | svetlogorsk
# Processing Record 4 of Set 7 | yar-sale
# Processing Record 5 of Set 7 | khromtau
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 7 | warrington
# Processing Record 9 of Set 7 | beitbridge
# Processing Record 10 of Set 7 | trairi
# Processing Record 11 of Set 7 | north bend
# Processing Record 12 of Set 7 | paracuru
# Processing Record 13 of Set 7 | talcahuano
# Processing Record 14 of Set 7 | juneau
# Processing Record 15 of Set 7 | touros
# Processing Record 16 of Set 7 | maragogi
# Processing Record 17 of Set 7 | tyukhtet
# Processing Record 18 of Set 7 | nikolskoye
# Processing Record 19 of Set 7 | petropavlovskoye
# Processing Record 20 of Set 7 | gat
# Processing Record 21 of Set 7 | salalah
# Processing Record 22 of Set 7 | olhao
# Processing Record 23 of Set 7 | port moresby
# Processing Record 24 of Set 7 | kaarst
# Processing Record 25 of Set 7 | egvekinot
# Processing Record 26 of Set 7 | faya
# Processing Record 27 of Set 7 | dhidhdhoo
# Processing Record 28 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 7 | iberia
# Processing Record 30 of Set 7 | sao gabriel da cachoeira
# Processing Record 31 of Set 7 | sanchor
# Processing Record 32 of Set 7 | razdolinsk
# Processing Record 33 of Set 7 | bathsheba
# Processing Record 34 of Set 7 | roald
# Processing Record 35 of Set 7 | meulaboh
# Processing Record 36 of Set 7 | dombarovskiy
# Processing Record 37 of Set 7 | potsdam
# Processing Record 38 of Set 7 | pirapo
# Processing Record 39 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | araouane
# Processing Record 42 of Set 7 | shelburne
# Processing Record 43 of Set 7 | surt
# Processing Record 44 of Set 7 | asfi
# Processing Record 45 of Set 7 | sorkjosen
# Processing Record 46 of Set 7 | tres arroyos
# Processing Record 47 of Set 7 | chumikan
# Processing Record 48 of Set 7 | umba
# Processing Record 49 of Set 7 | oriximina
# Processing Record 50 of Set 7 | lamont
# Processing Record 1 of Set 8 | biscarrosse
# Processing Record 2 of Set 8 | merritt island
# Processing Record 3 of Set 8 | predivinsk
# Processing Record 4 of Set 8 | haileybury
# Processing Record 5 of Set 8 | languyan
# Processing Record 6 of Set 8 | ust-maya
# Processing Record 7 of Set 8 | ladario
# Processing Record 8 of Set 8 | guerrero negro
# Processing Record 9 of Set 8 | the hammocks
# Processing Record 10 of Set 8 | mangan
# Processing Record 11 of Set 8 | flin flon
# Processing Record 12 of Set 8 | whitianga
# Processing Record 13 of Set 8 | dauphin
# Processing Record 14 of Set 8 | barra patuca
# Processing Record 15 of Set 8 | ornes
# Processing Record 16 of Set 8 | santa cruz de la palma
# Processing Record 17 of Set 8 | pangoa
# Processing Record 18 of Set 8 | fillmore
# Processing Record 19 of Set 8 | bucerias
# Processing Record 20 of Set 8 | gigmoto
# Processing Record 21 of Set 8 | nishihara
# Processing Record 22 of Set 8 | at-bashi
# Processing Record 23 of Set 8 | paraiso
# Processing Record 24 of Set 8 | mondlo
# Processing Record 25 of Set 8 | marystown
# Processing Record 26 of Set 8 | gilgil
# City not found. Skipping...
# Processing Record 27 of Set 8 | half moon bay
# Processing Record 28 of Set 8 | visnes
# Processing Record 29 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 8 | broome
# Processing Record 31 of Set 8 | asyut
# Processing Record 32 of Set 8 | acari
# Processing Record 33 of Set 8 | shimla
# Processing Record 34 of Set 8 | gizycko
# Processing Record 35 of Set 8 | morondava
# Processing Record 36 of Set 8 | khatanga
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | clearlake
# Processing Record 39 of Set 8 | mabaruma
# Processing Record 40 of Set 8 | bhadrachalam
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | rusape
# Processing Record 43 of Set 8 | calvinia
# Processing Record 44 of Set 8 | gouyave
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | heihe
# Processing Record 47 of Set 8 | daru
# Processing Record 48 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 8 | doembang nangbuat
# Processing Record 50 of Set 8 | belmonte
# Processing Record 1 of Set 9 | sorland
# Processing Record 2 of Set 9 | los llanos de aridane
# Processing Record 3 of Set 9 | areosa
# Processing Record 4 of Set 9 | udachnyy
# Processing Record 5 of Set 9 | sobolevo
# Processing Record 6 of Set 9 | ukiah
# Processing Record 7 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 8 of Set 9 | sabang
# Processing Record 9 of Set 9 | leh
# Processing Record 10 of Set 9 | maputo
# Processing Record 11 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 12 of Set 9 | aguimes
# Processing Record 13 of Set 9 | annau
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | maniitsoq
# Processing Record 16 of Set 9 | wajima
# Processing Record 17 of Set 9 | okhotsk
# Processing Record 18 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | lac du bonnet
# Processing Record 21 of Set 9 | magangue
# Processing Record 22 of Set 9 | carlyle
# Processing Record 23 of Set 9 | tigil
# Processing Record 24 of Set 9 | sungairaya
# Processing Record 25 of Set 9 | la ronge
# Processing Record 26 of Set 9 | cockburn town
# Processing Record 27 of Set 9 | fort walton beach
# Processing Record 28 of Set 9 | miranda de ebro
# Processing Record 29 of Set 9 | santa vitoria do palmar
# Processing Record 30 of Set 9 | menongue
# Processing Record 31 of Set 9 | fallon
# Processing Record 32 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 9 | mamallapuram
# Processing Record 34 of Set 9 | brainerd
# Processing Record 35 of Set 9 | mizdah
# Processing Record 36 of Set 9 | saint-felicien
# Processing Record 37 of Set 9 | zhanaozen
# Processing Record 38 of Set 9 | imisli
# City not found. Skipping...
# Processing Record 39 of Set 9 | edd
# Processing Record 40 of Set 9 | redlands
# Processing Record 41 of Set 9 | bereda
# Processing Record 42 of Set 9 | narsaq
# Processing Record 43 of Set 9 | amarpatan
# Processing Record 44 of Set 9 | ploemeur
# Processing Record 45 of Set 9 | souillac
# Processing Record 46 of Set 9 | galle
# Processing Record 47 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | saint anthony
# Processing Record 50 of Set 9 | villa maria
# Processing Record 1 of Set 10 | rudnogorsk
# Processing Record 2 of Set 10 | qasigiannguit
# Processing Record 3 of Set 10 | sindor
# Processing Record 4 of Set 10 | mount gambier
# Processing Record 5 of Set 10 | inhambane
# Processing Record 6 of Set 10 | saint-augustin
# Processing Record 7 of Set 10 | xunchang
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | hazorasp
# Processing Record 10 of Set 10 | malkangiri
# Processing Record 11 of Set 10 | winnemucca
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | chapais
# Processing Record 14 of Set 10 | nador
# Processing Record 15 of Set 10 | thanh hoa
# Processing Record 16 of Set 10 | zharkovskiy
# Processing Record 17 of Set 10 | tibati
# Processing Record 18 of Set 10 | sambava
# Processing Record 19 of Set 10 | udayagiri
# Processing Record 20 of Set 10 | port macquarie
# Processing Record 21 of Set 10 | pemangkat
# Processing Record 22 of Set 10 | simao
# Processing Record 23 of Set 10 | port lincoln
# Processing Record 24 of Set 10 | cap malheureux
# Processing Record 25 of Set 10 | grindavik
# Processing Record 26 of Set 10 | laguna
# Processing Record 27 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 10 | xichang
# Processing Record 29 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 30 of Set 10 | canete
# Processing Record 31 of Set 10 | cassilandia
# Processing Record 32 of Set 10 | port said
# Processing Record 33 of Set 10 | bagdarin
# Processing Record 34 of Set 10 | weatherford
# Processing Record 35 of Set 10 | berlevag
# Processing Record 36 of Set 10 | sainte-rose
# Processing Record 37 of Set 10 | whitehorse
# Processing Record 38 of Set 10 | zheleznodorozhnyy
# Processing Record 39 of Set 10 | nemuro
# Processing Record 40 of Set 10 | lumeje
# Processing Record 41 of Set 10 | preobrazheniye
# Processing Record 42 of Set 10 | puksoozero
# Processing Record 43 of Set 10 | chokurdakh
# Processing Record 44 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 10 | naryan-mar
# Processing Record 46 of Set 10 | bellegarde-sur-valserine
# Processing Record 47 of Set 10 | sangar
# Processing Record 48 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | bhainsdehi
# Processing Record 50 of Set 10 | kamaishi
# Processing Record 1 of Set 11 | carlsbad
# Processing Record 2 of Set 11 | krasnoselkup
# Processing Record 3 of Set 11 | merauke
# Processing Record 4 of Set 11 | mandalgovi
# Processing Record 5 of Set 11 | ostrovnoy
# Processing Record 6 of Set 11 | tahta
# Processing Record 7 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 11 | atar
# Processing Record 9 of Set 11 | thinadhoo
# Processing Record 10 of Set 11 | puerto carreno
# Processing Record 11 of Set 11 | samarai
# Processing Record 12 of Set 11 | kuryk
# Processing Record 13 of Set 11 | taoudenni
# Processing Record 14 of Set 11 | kashi
# Processing Record 15 of Set 11 | ouadda
# Processing Record 16 of Set 11 | behbahan
# Processing Record 17 of Set 11 | arys
# Processing Record 18 of Set 11 | progreso
# Processing Record 19 of Set 11 | sisimiut
# Processing Record 20 of Set 11 | yumen
# Processing Record 21 of Set 11 | tarrafal
# Processing Record 22 of Set 11 | bengkulu
# Processing Record 23 of Set 11 | port-gentil
# Processing Record 24 of Set 11 | tunceli
# Processing Record 25 of Set 11 | xiangxiang
# Processing Record 26 of Set 11 | ballina
# Processing Record 27 of Set 11 | aksu
# Processing Record 28 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 11 | sawakin
# Processing Record 30 of Set 11 | chilca
# Processing Record 31 of Set 11 | luan
# Processing Record 32 of Set 11 | dalvik
# Processing Record 33 of Set 11 | quatre cocos
# Processing Record 34 of Set 11 | sakakah
# Processing Record 35 of Set 11 | ralivka
# Processing Record 36 of Set 11 | jumla
# Processing Record 37 of Set 11 | makakilo city
# Processing Record 38 of Set 11 | xining
# Processing Record 39 of Set 11 | toora-khem
# Processing Record 40 of Set 11 | san rafael
# Processing Record 41 of Set 11 | barra mansa
# Processing Record 42 of Set 11 | lubango
# Processing Record 43 of Set 11 | hartsdale
# Processing Record 44 of Set 11 | boca do acre
# Processing Record 45 of Set 11 | yueyang
# Processing Record 46 of Set 11 | ouallam
# Processing Record 47 of Set 11 | khani
# Processing Record 48 of Set 11 | ruston
# Processing Record 49 of Set 11 | kaka
# Processing Record 50 of Set 11 | campos belos
# Processing Record 1 of Set 12 | adygeysk
# Processing Record 2 of Set 12 | boa vista
# Processing Record 3 of Set 12 | nara
# Processing Record 4 of Set 12 | kalmunai
# Processing Record 5 of Set 12 | lakki marwat
# Processing Record 6 of Set 12 | joensuu
# Processing Record 7 of Set 12 | nouakchott
# Processing Record 8 of Set 12 | salaga
# Processing Record 9 of Set 12 | sunrise manor
# Processing Record 10 of Set 12 | etchoropo
# Processing Record 11 of Set 12 | la plata
# Processing Record 12 of Set 12 | antalaha
# Processing Record 13 of Set 12 | alice springs
# Processing Record 14 of Set 12 | hofn
# Processing Record 15 of Set 12 | monticello
# Processing Record 16 of Set 12 | bull savanna
# Processing Record 17 of Set 12 | muros
# Processing Record 18 of Set 12 | eyl
# Processing Record 19 of Set 12 | henties bay
# Processing Record 20 of Set 12 | batemans bay
# Processing Record 21 of Set 12 | luwingu
# Processing Record 22 of Set 12 | letlhakane
# Processing Record 23 of Set 12 | praia
# Processing Record 24 of Set 12 | salihli
# Processing Record 25 of Set 12 | presidencia roque saenz pena
# Processing Record 26 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 12 | sembakung
# Processing Record 30 of Set 12 | hurghada
# Processing Record 31 of Set 12 | ventspils
# Processing Record 32 of Set 12 | miri
# Processing Record 33 of Set 12 | nuevo progreso
# Processing Record 34 of Set 12 | banda aceh
# Processing Record 35 of Set 12 | breyten
# Processing Record 36 of Set 12 | khorixas
# Processing Record 37 of Set 12 | valdivia
# Processing Record 38 of Set 12 | fuente de oro
# Processing Record 39 of Set 12 | bandarbeyla
# Processing Record 40 of Set 12 | marsa matruh
# Processing Record 41 of Set 12 | san policarpo
# Processing Record 42 of Set 12 | zhuhai
# Processing Record 43 of Set 12 | tabas
# Processing Record 44 of Set 12 | comodoro rivadavia
# Processing Record 45 of Set 12 | baherden
# Processing Record 46 of Set 12 | auki
# Processing Record 47 of Set 12 | moses lake
# Processing Record 48 of Set 12 | tautira
# Processing Record 49 of Set 12 | saryg-sep
# Processing Record 50 of Set 12 | azul
# Processing Record 1 of Set 13 | mildura
# Processing Record 2 of Set 13 | stepnyak
# Processing Record 3 of Set 13 | coolum beach
# Processing Record 4 of Set 13 | vila
# Processing Record 5 of Set 13 | irpa irpa
# Processing Record 6 of Set 13 | tabory
# Processing Record 7 of Set 13 | benalla
# Processing Record 8 of Set 13 | sechura
# Processing Record 9 of Set 13 | limon
# Processing Record 10 of Set 13 | tahoua
# Processing Record 11 of Set 13 | semporna
# Processing Record 12 of Set 13 | waddan
# Processing Record 13 of Set 13 | kribi
# Processing Record 14 of Set 13 | tual
# Processing Record 15 of Set 13 | rosita
# Processing Record 16 of Set 13 | kuah
# Processing Record 17 of Set 13 | balsas
# Processing Record 18 of Set 13 | sosnovka
# Processing Record 19 of Set 13 | ixtapa
# Processing Record 20 of Set 13 | vestmannaeyjar
# Processing Record 21 of Set 13 | dourados
# Processing Record 22 of Set 13 | naron
# Processing Record 23 of Set 13 | mayumba
# Processing Record 24 of Set 13 | naze
# Processing Record 25 of Set 13 | fez
# Processing Record 26 of Set 13 | walla walla
# Processing Record 27 of Set 13 | surskoye
# Processing Record 28 of Set 13 | poum
# Processing Record 29 of Set 13 | sancti spiritus
# Processing Record 30 of Set 13 | arlit
# Processing Record 31 of Set 13 | tongliao
# Processing Record 32 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 13 | morros
# Processing Record 34 of Set 13 | ulu-telyak
# Processing Record 35 of Set 13 | adrar
# Processing Record 36 of Set 13 | impfondo
# Processing Record 37 of Set 13 | yuli
# Processing Record 38 of Set 13 | kyra
# Processing Record 39 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 40 of Set 13 | san matias
# Processing Record 41 of Set 13 | yerbogachen
# Processing Record 42 of Set 13 | halifax
# Processing Record 43 of Set 13 | natal
# Processing Record 44 of Set 13 | solnechnyy
# Processing Record 45 of Set 13 | mitsamiouli
# Processing Record 46 of Set 13 | champerico
# Processing Record 47 of Set 13 | arawa
# Processing Record 48 of Set 13 | burgersdorp
# Processing Record 49 of Set 13 | yuci
# Processing Record 50 of Set 13 | xinyu
# Processing Record 1 of Set 14 | prince rupert
# Processing Record 2 of Set 14 | grand-santi
# Processing Record 3 of Set 14 | mitzic
# Processing Record 4 of Set 14 | zlobin
# Processing Record 5 of Set 14 | san miguel
# Processing Record 6 of Set 14 | risti
# Processing Record 7 of Set 14 | garden city
# Processing Record 8 of Set 14 | dawei
# Processing Record 9 of Set 14 | verkhoyansk
# Processing Record 10 of Set 14 | peniche
# Processing Record 11 of Set 14 | ati
# Processing Record 12 of Set 14 | ushtobe
# Processing Record 13 of Set 14 | puerto escondido
# Processing Record 14 of Set 14 | alim
# Processing Record 15 of Set 14 | haukipudas
# Processing Record 16 of Set 14 | palm coast
# Processing Record 17 of Set 14 | thilogne
# City not found. Skipping...
# Processing Record 18 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 14 | borogontsy
# Processing Record 20 of Set 14 | hammerfest
# Processing Record 21 of Set 14 | stornoway
# Processing Record 22 of Set 14 | mubende
# Processing Record 23 of Set 14 | nikolayevsk-na-amure
# Processing Record 24 of Set 14 | lemon tree passage
# Processing Record 25 of Set 14 | xai-xai
# Processing Record 26 of Set 14 | mutis
# Processing Record 27 of Set 14 | cilaos
# Processing Record 28 of Set 14 | kosh-agach
# Processing Record 29 of Set 14 | bubaque
# Processing Record 30 of Set 14 | hamilton
# Processing Record 31 of Set 14 | ancud
# Processing Record 32 of Set 14 | buala
# Processing Record 33 of Set 14 | severomuysk
# Processing Record 34 of Set 14 | presque isle
# Processing Record 35 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 14 | ormos korthiou
# City not found. Skipping...
# Processing Record 37 of Set 14 | abha
# Processing Record 38 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 14 | benjamin aceval
# Processing Record 40 of Set 14 | denpasar
# Processing Record 41 of Set 14 | lunderskov
# Processing Record 42 of Set 14 | lamar
# Processing Record 43 of Set 14 | braintree
# Processing Record 44 of Set 14 | ganzhou
# Processing Record 45 of Set 14 | ajdabiya
# Processing Record 46 of Set 14 | sumisip
# Processing Record 47 of Set 14 | aldama
# Processing Record 48 of Set 14 | kailua
# Processing Record 49 of Set 14 | ravar
# Processing Record 50 of Set 14 | lodja
# Processing Record 1 of Set 15 | the pas
# Processing Record 2 of Set 15 | olga
# Processing Record 3 of Set 15 | rujewa
# Processing Record 4 of Set 15 | xuddur
# Processing Record 5 of Set 15 | ibanesti
# Processing Record 6 of Set 15 | nikel
# Processing Record 7 of Set 15 | moree
# Processing Record 8 of Set 15 | nabari
# Processing Record 9 of Set 15 | bismarck
# Processing Record 10 of Set 15 | bajil
# Processing Record 11 of Set 15 | urengoy
# Processing Record 12 of Set 15 | mbini
# Processing Record 13 of Set 15 | goderich
# Processing Record 14 of Set 15 | wageningen
# Processing Record 15 of Set 15 | najran
# Processing Record 16 of Set 15 | lima
# Processing Record 17 of Set 15 | bartica
# Processing Record 18 of Set 15 | athmallik
# Processing Record 19 of Set 15 | union
# Processing Record 20 of Set 15 | mezen
# Processing Record 21 of Set 15 | kingsport
# Processing Record 22 of Set 15 | kupang
# Processing Record 23 of Set 15 | umm lajj
# Processing Record 24 of Set 15 | axim
# Processing Record 25 of Set 15 | xinxiang
# Processing Record 26 of Set 15 | vitimskiy
# City not found. Skipping...
# Processing Record 27 of Set 15 | steinkjer
# Processing Record 28 of Set 15 | broken hill
# Processing Record 29 of Set 15 | yorosso
# Processing Record 30 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 15 | kyabram
# Processing Record 32 of Set 15 | margate
# Processing Record 33 of Set 15 | petropavlovka
# Processing Record 34 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 35 of Set 15 | ye
# City not found. Skipping...
# Processing Record 36 of Set 15 | san cristobal
# Processing Record 37 of Set 15 | beyneu
# Processing Record 38 of Set 15 | kaseda
# Processing Record 39 of Set 15 | vaitape
# Processing Record 40 of Set 15 | takoradi
# Processing Record 41 of Set 15 | magadan
# Processing Record 42 of Set 15 | aswan
# Processing Record 43 of Set 15 | bosanska kostajnica
# Processing Record 44 of Set 15 | cukai
# Processing Record 45 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 15 | emerald
# Processing Record 47 of Set 15 | san luis
# Processing Record 48 of Set 15 | shimanovsk
# Processing Record 49 of Set 15 | marsh harbour
# Processing Record 50 of Set 15 | gazanjyk
# Processing Record 1 of Set 16 | acarau
# Processing Record 2 of Set 16 | aktau
# Processing Record 3 of Set 16 | sao francisco de paula
# Processing Record 4 of Set 16 | rudbar
# Processing Record 5 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 16 | kysyl-syr
# Processing Record 7 of Set 16 | bharatpur
# Processing Record 8 of Set 16 | nizwa
# Processing Record 9 of Set 16 | gweta
# Processing Record 10 of Set 16 | araceli
# Processing Record 11 of Set 16 | sapao
# City not found. Skipping...
# Processing Record 12 of Set 16 | kontagora
# Processing Record 13 of Set 16 | horsham
# Processing Record 14 of Set 16 | cape elizabeth
# City not found. Skipping...
# Processing Record 15 of Set 16 | nizhniy kuranakh
# Processing Record 16 of Set 16 | ndioum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file = "Vacation_Search/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
